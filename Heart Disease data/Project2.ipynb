# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline 
from scipy import stats
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv('Heart Disease data.csv')

# %%
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0

# %%
df.describe()
# Out:
#                age          sex           cp     trestbps        chol  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.00000
# mean     54.434146     0.695610     0.942439   131.611707   246.00000
# std       9.072290     0.460373     1.029641    17.516718    51.59251
# min      29.000000     0.000000     0.000000    94.000000   126.00000
# 25%      48.000000     0.000000     0.000000   120.000000   211.00000
# 50%      56.000000     1.000000     1.000000   130.000000   240.00000
# 75%      61.000000     1.000000     2.000000   140.000000   275.00000
# max      77.000000     1.000000     3.000000   200.000000   564.00000
#
#                fbs      restecg      thalach        exang      oldpeak  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.000000
# mean      0.149268     0.529756   149.114146     0.336585     1.071512
# std       0.356527     0.527878    23.005724     0.472772     1.175053
# ...

# %%
df.isna().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
df.shape
# Out:
# (1025, 14)

# %%
df[df.duplicated()]
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 15     34    0   1       118   210    0        1      192      0      0.7
# 31     50    0   1       120   244    0        1      162      0      1.1
# 43     46    1   0       120   249    0        0      144      0      0.8
# 55     55    1   0       140   217    0        1      111      1      5.6
# 61     66    0   2       146   278    0        0      152      0      0.0
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 15        2   0     2       1
# ...

# %%
df = df.drop_duplicates()

# %%
df.shape
# Out:
# (302, 14)

# %%
df.nunique()
# Out:
# age          41
# sex           2
# cp            4
# trestbps     49
# chol        152
# fbs           2
# restecg       3
# thalach      91
# exang         2
# oldpeak      40
# slope         3
# ca            5
# thal          4
# target        2
# dtype: int64

# %% [markdown]
# #### Observation
# - From the above results we can underand that the data set have multiple number of categorical data which have intiger values

# %%
df.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
categorical_feature = df[['sex', 'cp', 'fbs', 'restecg','exang', 'slope', 'ca', 'thal']]
numerical_feature = df[['age', 'trestbps', 'chol', 'thalach', 'oldpeak']]
target_feature =df[['target']]

# %%
df.target.value_counts().plot(kind='bar')
plt.xlabel('test results')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# #### observation:
# - From the above plot we can understand that the given dataset balanced enough

# %%
sns.pairplot(df)

# %%
sns.histplot(df['age'],kde=True)
# Out:
# <AxesSubplot: xlabel='age', ylabel='Count'>

# %%
plt.figure(figsize=(7,7))
sns.scatterplot(x='age', y='trestbps',hue ='cp' ,data=df)
# Out:
# <AxesSubplot: xlabel='age', ylabel='trestbps'>

# %%
df.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
plt.figure(figsize=(7,5))
sns.scatterplot(x='age', y='trestbps',hue ='thal',data=df)
# Out:
# <AxesSubplot: xlabel='age', ylabel='trestbps'>
