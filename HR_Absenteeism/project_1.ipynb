# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline 
sns.set(color_codes=True)
from scipy import stats
import warnings
warnings.filterwarnings("ignore")

# %%
data = pd.read_csv('HR_Absenteeism data.csv')
data.head()
# Out:
#    EmployeeNumber    Surname GivenName Gender             City JobTitle  \
# 0               1  Gutierrez     Molly      F          Burnaby    Baker
# 1               2   Hardwick   Stephen      M        Courtenay    Baker
# 2               3    Delgado   Chester      M         Richmond    Baker
# 3               4      Simon     Irene      F         Victoria    Baker
# 4               5   Delvalle    Edward      M  New Westminster    Baker
#
#   DepartmentName    StoreLocation Division        Age  LengthService  \
# 0         Bakery          Burnaby   Stores  32.028816       6.018478
# 1         Bakery          Nanaimo   Stores  40.320902       5.532445
# 2         Bakery         Richmond   Stores  48.822047       4.389973
# 3         Bakery         Victoria   Stores  44.599357       3.081736
# 4         Bakery  New Westminster   Stores  35.697876       3.619091
#
#    AbsentHours BusinessUnit
# 0    36.577306       Stores
# 1    30.165072       Stores
# 2    83.807798       Stores
# ...

# %%
data[data.duplicated()]
# Out:
# Empty DataFrame
# Columns: [EmployeeNumber, Surname, GivenName, Gender, City, JobTitle, DepartmentName, StoreLocation, Division, Age, LengthService, AbsentHours, BusinessUnit]
# Index: []

# %%
data.columns
# Out:
# Index(['EmployeeNumber', 'Surname', 'GivenName', 'Gender', 'City', 'JobTitle',
#        'DepartmentName', 'StoreLocation', 'Division', 'Age', 'LengthService',
#        'AbsentHours', 'BusinessUnit'],
#       dtype='object')

# %%
#data[(data['Surname']=='Johnson')&(data['GivenName']=='James')]
d = data[['Surname','GivenName']]

# %%
data[(data['Surname']=='Young')&(data['GivenName']=='Robert')]
# Out:
#       EmployeeNumber Surname GivenName Gender             City       JobTitle  \
# 826              827   Young    Robert      M    Francois Lake        Cashier
# 2358            2359   Young    Robert      M         Victoria    Meat Cutter
# 3324            3325   Young    Robert      M  New Westminster  Produce Clerk
# 8257            8258   Young    Robert      M        Valemount   Dairy Person
#
#         DepartmentName    StoreLocation Division        Age  LengthService  \
# 826   Customer Service    Prince George   Stores  53.829928       3.935635
# 2358             Meats         Victoria   Stores  48.545219       4.423227
# 3324           Produce  New Westminster   Stores  45.770853       6.160856
# 8257             Dairy        Valemount   Stores  29.917381       4.460836
#
#       AbsentHours BusinessUnit
# 826     52.516042       Stores
# 2358    35.377358       Stores
# 3324    38.010141       Stores
# 8257     0.000000       Stores

# %%
d[d.duplicated()].value_counts()
# Out:
# Surname      GivenName
# Young        Robert       3
# Wilson       Mary         3
# Johnson      David        3
# Miller       Robert       3
# Brown        William      3
#                          ..
# Ramirez      Cheryl       1
# Rivera       Ronald       1
# Rodriguez    Mary         1
# Ross         Mark         1
# Abercrombie  Cynthia      1
# Length: 105, dtype: int64

# %%
data. info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8336 entries, 0 to 8335
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   EmployeeNumber  8336 non-null   int64
#  1   Surname         8336 non-null   object
#  2   GivenName       8336 non-null   object
#  3   Gender          8336 non-null   object
#  4   City            8336 non-null   object
#  5   JobTitle        8336 non-null   object
#  6   DepartmentName  8336 non-null   object
#  7   StoreLocation   8336 non-null   object
#  8   Division        8336 non-null   object
#  9   Age             8336 non-null   float64
#  10  LengthService   8336 non-null   float64
#  11  AbsentHours     8336 non-null   float64
#  12  BusinessUnit    8336 non-null   object
# dtypes: float64(3), int64(1), object(9)
# memory usage: 846.8+ KB

# %%
len(data. columns)
# Out:
# 13

# %%
data. isna().sum()
# Out:
# EmployeeNumber    0
# Surname           0
# GivenName         0
# Gender            0
# City              0
# JobTitle          0
# DepartmentName    0
# StoreLocation     0
# Division          0
# Age               0
# LengthService     0
# AbsentHours       0
# BusinessUnit      0
# dtype: int64

# %%
for i in data.columns:
    print('_____________%s_______________' %i)
    print(data[i].value_counts())
# Out:
# _____________EmployeeNumber_______________
# 2047    1
# 1330    1
# 5432    1
# 7481    1
# 1338    1
#        ..
# 6814    1
# 4767    1
# 2724    1
# 677     1
# 2049    1
# Name: EmployeeNumber, Length: 8336, dtype: int64
# _____________Surname_______________
# Johnson     106
# Smith        86
# Jones        71
# Williams     71
# Brown        62
#            ...
# Ibarra        1
# Angelo        1
# Urquhart      1
# Kizer         1
# Mabe          1
# Name: Surname, Length: 4051, dtype: int64
# _____________GivenName_______________
# James      182
# John       161
# Robert     136
# Mary       124
# William    121
#           ...
# Petra        1
# Sharee       1
# Hildred      1
# Paola        1
# Shawnee      1
# Name: GivenName, Length: 1625, dtype: int64
# _____________Gender_______________
# M    4216
# F    4120
# Name: Gender, dtype: int64
# _____________City_______________
# Vancouver          1780
# Victoria            690
# New Westminster     540
# ...

# %%
data.describe()
# Out:
#        EmployeeNumber          Age  LengthService  AbsentHours
# count     8336.000000  8336.000000    8336.000000  8336.000000
# mean      4168.500000    42.007086       4.782910    61.283978
# std       2406.540255     9.939798       2.462990    49.038365
# min          1.000000     3.504743       0.012098     0.000000
# 25%       2084.750000    35.298748       3.575892    19.127590
# 50%       4168.500000    42.114924       4.600248    56.005808
# 75%       6252.250000    48.666943       5.623922    94.284692
# max       8336.000000    77.938003      43.735239   272.530123

# %%
data.shape
# Out:
# (8336, 13)

# %%
d = data.iloc[:,1:]#.drop_duplicates()
d.head()
# Out:
#      Surname GivenName Gender             City JobTitle DepartmentName  \
# 0  Gutierrez     Molly      F          Burnaby    Baker         Bakery
# 1   Hardwick   Stephen      M        Courtenay    Baker         Bakery
# 2    Delgado   Chester      M         Richmond    Baker         Bakery
# 3      Simon     Irene      F         Victoria    Baker         Bakery
# 4   Delvalle    Edward      M  New Westminster    Baker         Bakery
#
#      StoreLocation Division        Age  LengthService  AbsentHours  \
# 0          Burnaby   Stores  32.028816       6.018478    36.577306
# 1          Nanaimo   Stores  40.320902       5.532445    30.165072
# 2         Richmond   Stores  48.822047       4.389973    83.807798
# 3         Victoria   Stores  44.599357       3.081736    70.020165
# 4  New Westminster   Stores  35.697876       3.619091     0.000000
#
#   BusinessUnit
# 0       Stores
# 1       Stores
# 2       Stores
# 3       Stores
# 4       Stores

# %%
d.shape
# Out:
# (8336, 12)

# %%
df = d.drop_duplicates()
df.head()
# Out:
#      Surname GivenName Gender             City JobTitle DepartmentName  \
# 0  Gutierrez     Molly      F          Burnaby    Baker         Bakery
# 1   Hardwick   Stephen      M        Courtenay    Baker         Bakery
# 2    Delgado   Chester      M         Richmond    Baker         Bakery
# 3      Simon     Irene      F         Victoria    Baker         Bakery
# 4   Delvalle    Edward      M  New Westminster    Baker         Bakery
#
#      StoreLocation Division        Age  LengthService  AbsentHours  \
# 0          Burnaby   Stores  32.028816       6.018478    36.577306
# 1          Nanaimo   Stores  40.320902       5.532445    30.165072
# 2         Richmond   Stores  48.822047       4.389973    83.807798
# 3         Victoria   Stores  44.599357       3.081736    70.020165
# 4  New Westminster   Stores  35.697876       3.619091     0.000000
#
#   BusinessUnit
# 0       Stores
# 1       Stores
# 2       Stores
# 3       Stores
# 4       Stores

# %%
df.shape
# Out:
# (8336, 12)
